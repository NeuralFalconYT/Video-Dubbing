# %% [markdown]
# ⚠️ Installing llama-cpp may take up to 30 minutes. <br>
# (This step is only required if you want to run local LLM-based text translation.)

# %%
#@title Install Video-Dubbing

import os
GITHUB_TOKEN=""  # @param {type: "string"}
REPO_URL = "https://github.com/NeuralFalconYT/video_dub.git"
# Use the token in the correct format
CLONE_URL = REPO_URL.replace("https://", f"https://{GITHUB_TOKEN}@")
# %cd /content/
# !rm -rf /content/Video-Dubbing
# !git clone {CLONE_URL}
# !git clone https://github.com/NeuralFalconYT/Video-Dubbing.git
# %cd ./Video-Dubbing/
# !pip install -qq -r requirements.txt
# !pip install audio-separator==0.39.0
llama_cpp_install= False  # @param {type: "boolean"}
if llama_cpp_install:
  # !CMAKE_ARGS="-DGGML_CUDA=on" pip install llama-cpp-python

from IPython.display import clear_output
clear_output()
import time
time.sleep(5)
import os
os.kill(os.getpid(), 9)

# %%
#@title Mount Google Drive for auto save [ Optional, helpful for Auto Save]
# %cd /content/
from IPython.display import clear_output
from google.colab import drive
import os

auto_save_in_drive = False  # @param {type: "boolean"}

if auto_save_in_drive:
    drive.mount('/content/gdrive', force_remount=True)
    os.makedirs("/content/gdrive/MyDrive/Video_Dubbing", exist_ok=True)
    clear_output()
    print("✅ A copy of Dubbed Video and Audio will save at Google Drive.")
# Out:
# ✅ A copy of Dubbed Video and Audio will save at Google Drive.

# %%
# %cd /content/Video-Dubbing/
# !python app.py --share --debug
